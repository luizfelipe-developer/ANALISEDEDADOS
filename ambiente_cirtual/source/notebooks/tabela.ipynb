# %%
# !pip3 install numpy
# !pip3 install pandas
# !pip3 install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/12.6 MB 9.3 MB/s eta 0:00:02
#    ------------------------------ --------- 9.4/12.6 MB 28.0 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.6 MB 28.0 MB/s eta 0:00:01
#    ------------------------------ --------- 9.4/12.6 MB 28.0 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.6 MB 10.1 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.6 MB 8.6 MB/s eta 0:00:01
#    --------------------------------- ------ 10.5/12.6 MB 7.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.6 MB 6.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.6 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 5.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('../dados/CAGED_movements.csv', sep=',')
df.head()
# Out:
#    Educational level ID Educational level  Family ID  \
# 0                     1        Analfabeto          0
# 1                     1        Analfabeto        101
# 2                     1        Analfabeto        103
# 3                     1        Analfabeto        301
# 4                     1        Analfabeto       1111
#
#                                               Family       Salary  \
# 0                                   Não especificado  2243.657666
# 1               Oficiais Generais Das Forças Armadas  1533.588810
# 2                          Praças Das Forças Armadas  2035.020004
# 3  Oficiais Superiores Do Corpo De Bombeiros Militar  1200.000000
# 4                                       Legisladores  1357.379980
#
#    Movement Balance  Admissions  Resignations
# 0                79         223           144
# 1                 1          10             9
# 2                 2           4             2
# 3                -1           0             1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7125 entries, 0 to 7124
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Educational level ID  7125 non-null   int64
#  1   Educational level     7125 non-null   object
#  2   Family ID             7125 non-null   int64
#  3   Family                7125 non-null   object
#  4   Salary                7125 non-null   float64
#  5   Movement Balance      7125 non-null   int64
#  6   Admissions            7125 non-null   int64
#  7   Resignations          7125 non-null   int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 445.4+ KB

# %%
df.dtypes
# Out:
# Educational level ID      int64
# Educational level        object
# Family ID                 int64
# Family                   object
# Salary                  float64
# Movement Balance          int64
# Admissions                int64
# Resignations              int64
# dtype: object

# %%
df.shape
# Out:
# (7125, 8)

# %%
df.tail()
# Out:
#       Educational level ID Educational level  Family ID  \
# 7120                    99  Não identificado       8621
# 7121                    99  Não identificado       8625
# 7122                    99  Não identificado       9113
# 7123                    99  Não identificado       9511
# 7124                    99  Não identificado       9922
#
#                                                  Family       Salary  \
# 7120        Operadores De Máquinas A Vapor E Utilidades  2134.119995
# 7121  Operadores De Instalações De Refrigeração E Ar...  1539.630005
# 7122    Mecânicos De Manutenção De Máquinas Industriais  3481.500000
# 7123        Eletricistas De Manutenção Eletroeletrônica  2932.930054
# 7124  Trabalhadores Operacionais De Conservação De V...  1646.549988
#
#       Movement Balance  Admissions  Resignations
# 7120                -2           0             2
# 7121                -1           0             1
# 7122                -1           0             1
# ...

# %%
df[['Educational level']]
# Out:
#      Educational level
# 0           Analfabeto
# 1           Analfabeto
# 2           Analfabeto
# 3           Analfabeto
# 4           Analfabeto
# ...                ...
# 7120  Não identificado
# 7121  Não identificado
# 7122  Não identificado
# 7123  Não identificado
# 7124  Não identificado
#
# [7125 rows x 1 columns]

# %%
df[['Family', 'Educational level', 'Salary']]
# Out:
#                                                  Family Educational level  \
# 0                                      Não especificado        Analfabeto
# 1                  Oficiais Generais Das Forças Armadas        Analfabeto
# 2                             Praças Das Forças Armadas        Analfabeto
# 3     Oficiais Superiores Do Corpo De Bombeiros Militar        Analfabeto
# 4                                          Legisladores        Analfabeto
# ...                                                 ...               ...
# 7120        Operadores De Máquinas A Vapor E Utilidades  Não identificado
# 7121  Operadores De Instalações De Refrigeração E Ar...  Não identificado
# 7122    Mecânicos De Manutenção De Máquinas Industriais  Não identificado
# 7123        Eletricistas De Manutenção Eletroeletrônica  Não identificado
# 7124  Trabalhadores Operacionais De Conservação De V...  Não identificado
#
#            Salary
# 0     2243.657666
# 1     1533.588810
# 2     2035.020004
# ...
